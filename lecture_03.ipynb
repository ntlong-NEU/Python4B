# %% [markdown]
# Lecture 3: Lists, Tuples, Sets and Dictionaries

# %%
#list
digits = [2,3,1,2,5]
names = ['Long', "Lan", 'hoa', 'mai']
print(digits)
names
# Out:
# [2, 3, 1, 2, 5]
# ['Long', 'Lan', 'hoa', 'mai']

# %%
digits[1]
# Out:
# 3

# %%
digits[4]
# Out:
# 5

# %%
names[0]
# Out:
# 'Long'

# %%
names
# Out:
# ['Long', 'Lan', 'hoa', 'mai']

# %%
names[-1]
# Out:
# 'mai'

# %%
# range of index = {0,1,2,3,-1,-2,-3,-4}
names[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # range of index = {0,1,2,3,-1,-2,-3,-1}
# ----> 2 names[4]
#
# IndexError: list index out of range

# %%
names[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 names[-5]
#
# IndexError: list index out of range

# %%
names
# Out:
# ['Long', 'Lan', 'hoa', 'mai']

# %%
names[2] = 'HOA'
names
# Out:
# ['Long', 'Lan', 'HOA', 'mai']

# %%
names.append("New Customer")
names
# Out:
# ['Long', 'Lan', 'HOA', 'mai', 'New Customer', 'New Customer']

# %%
names.insert(2, 'name_insert')
names
# Out:
# ['Long',
#  'Lan',
#  'name_insert',
#  'name_insert',
#  'HOA',
#  'mai',
#  'New Customer',
#  'New Customer']

# %%
del names[2]
names
# Out:
# ['Long', 'Lan', 'name_insert', 'HOA', 'mai', 'New Customer', 'New Customer']

# %%
del names[2]
names
# Out:
# ['Long', 'Lan', 'HOA', 'mai', 'New Customer', 'New Customer']

# %%
pop_item = names.pop()
print(names)
print(pop_item)
# Out:
# ['Long', 'Lan', 'HOA', 'mai', 'New Customer']
# New Customer

# %%
names
# Out:
# ['Long', 'Lan', 'HOA', 'mai', 'New Customer']

# %%
names.append("Long")
names
# Out:
# ['Long', 'Lan', 'HOA', 'mai', 'New Customer', 'Long']

# %%
names.remove('Long')
names
# Out:
# ['Lan', 'HOA', 'mai', 'New Customer', 'Long']

# %%
names.remove('Long')
names
# Out:
# ['Lan', 'HOA', 'mai', 'New Customer']
